# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### I choosed this dataset:
# https://www.ons.gov.uk/peoplepopulationandcommunity/housing/datasets/mediansalepricebydwellingtypeandmiddlelayersuperoutputarea

# %%
df = pd.read_csv("D:/recommendations+CV/data.csv")

# %%
df.head()
# Out:
#    MSOA_CODE                 MSOA_NAME 1995_MED_PRICE_ALL_TYPES  \
# 0  E02000001        City of London 001                  106,500
# 1  E02000002  Barking and Dagenham 001                   65,000
# 2  E02000003  Barking and Dagenham 002                   65,000
# 3  E02000004  Barking and Dagenham 003                   65,500
# 4  E02000005  Barking and Dagenham 004                   59,748
#
#   1995_MED_PRICE_DETACHED 1995_MED_PRICE_SEMI_DETACHED  \
# 0                     NaN                          NaN
# 1                     NaN                       73,000
# 2                  99,000                       66,750
# 3                     NaN                       69,000
# 4                     NaN                       60,000
#
#   1995_MED_PRICE_TERRACED 1995_MED_PRICE_FLATS_MAISONETTES  \
# 0                 310,000                          105,000
# 1                  59,495                              NaN
# 2                  64,000                              NaN
# ...

# %%
df.describe()
# Out:
#         MSOA_CODE    MSOA_NAME 1995_MED_PRICE_ALL_TYPES  \
# count        7201         7201                     7180
# unique       7201         7201                     1399
# top     E02003575  Cardiff 022                   40,000
# freq            1            1                      121
#
#        1995_MED_PRICE_DETACHED 1995_MED_PRICE_SEMI_DETACHED  \
# count                     5344                         6764
# unique                    1364                         1299
# top                     60,000                       45,000
# freq                        66                          136
#
#        1995_MED_PRICE_TERRACED 1995_MED_PRICE_FLATS_MAISONETTES  \
# count                     6896                             3583
# unique                    1344                              943
# top                     40,000                           35,000
# freq                       106                               67
#
# ...

# %%
df.shape
# Out:
# (7201, 97)

# %%
df.isna().sum().sum()
# Out:
# 91181

# %% [markdown]
# ### visualisation of missing values: we can use seaborn to create a simple heatmap to see where are the missing values!

# %%
sns.heatmap(df.isna(), yticklabels = False, cbar = True, cmap ='viridis');

# %% [markdown]
# ### THere are 91181 missing values the yellow represents the missing values and  purple are non missing values so we have to handle it to perform some visualisation and calculations

# %%
df.notna().sum().sum()
# Out:
# 607316

# %% [markdown]
# ### There are 607316 non missing values

# %%
print('The ratio of missing values from all the data is {}'.format(91181/607316))
# Out:
# The ratio of missing values from all the data is 0.15013765486171943

# %% [markdown]
# ### Since the missing values represent almost 15% from all the dataset, we can just drop them

# %%
df.dropna(inplace = True)

# %% [markdown]
# ### Verify if there are missing values:

# %%
sns.heatmap(df.isna(), yticklabels = False, cbar = True, cmap ='viridis');

# %% [markdown]
# ### We removed all the rows (observations) that contain any missing value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1213 entries, 22 to 7170
# Data columns (total 97 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   MSOA_CODE                         1213 non-null   object
#  1   MSOA_NAME                         1213 non-null   object
#  2   1995_MED_PRICE_ALL_TYPES          1213 non-null   object
#  3   1995_MED_PRICE_DETACHED           1213 non-null   object
#  4   1995_MED_PRICE_SEMI_DETACHED      1213 non-null   object
#  5   1995_MED_PRICE_TERRACED           1213 non-null   object
#  6   1995_MED_PRICE_FLATS_MAISONETTES  1213 non-null   object
#  7   1996_MED_PRICE_ALL_TYPES          1213 non-null   object
#  8   1996_MED_PRICE_DETACHED           1213 non-null   object
#  9   1996_MED_PRICE_SEMI_DETACHED      1213 non-null   object
#  10  1996_MED_PRICE_TERRACED           1213 non-null   object
# ...

# %% [markdown]
# ### The prices are in string format

# %%
df['1995_MED_PRICE_ALL_TYPES']
# Out:
# 22       95,000
# 34       88,225
# 37      119,500
# 38       97,500
# 46      112,000
#          ...
# 7156     66,000
# 7163     85,000
# 7164     62,000
# 7168     83,750
# 7170     59,950
# Name: 1995_MED_PRICE_ALL_TYPES, Length: 1213, dtype: object

# %% [markdown]
# ### Converting all the prices to float to perform more calculations like average, median...

# %%
for i in df.columns:
    if 'PRICE' in i:
        df[i] = (df[i].str.replace(",", "")).apply(lambda x:float(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1213 entries, 22 to 7170
# Data columns (total 97 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   MSOA_CODE                         1213 non-null   object
#  1   MSOA_NAME                         1213 non-null   object
#  2   1995_MED_PRICE_ALL_TYPES          1213 non-null   float64
#  3   1995_MED_PRICE_DETACHED           1213 non-null   float64
#  4   1995_MED_PRICE_SEMI_DETACHED      1213 non-null   float64
#  5   1995_MED_PRICE_TERRACED           1213 non-null   float64
#  6   1995_MED_PRICE_FLATS_MAISONETTES  1213 non-null   float64
#  7   1996_MED_PRICE_ALL_TYPES          1213 non-null   float64
#  8   1996_MED_PRICE_DETACHED           1213 non-null   float64
#  9   1996_MED_PRICE_SEMI_DETACHED      1213 non-null   float64
#  10  1996_MED_PRICE_TERRACED           1213 non-null   float64
# ...

# %% [markdown]
# ### Let's do some data visualisation

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.distplot(df['1995_MED_PRICE_ALL_TYPES'],kde=True,ax=ax)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
sub_sample = df.sample(frac=0.01)

# %%
sns.heatmap(sub_sample.corr(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.distplot(df['2000_MED_PRICE_ALL_TYPES'],kde=True,ax=ax)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'MSOA_NAME', y = '1995_MED_PRICE_ALL_TYPES',  data = df.sample(frac=0.01), ax=ax)
plt.title('City vs Price in 1995')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.distplot(df['2005_MED_PRICE_ALL_TYPES'],kde=True,ax=ax)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'MSOA_NAME', y = '2000_MED_PRICE_ALL_TYPES',  data = df.sample(frac=0.01), ax=ax)
plt.title('City vs Price in 1995')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ### Still not finish but this is what I could do in this short time of the week end :)
